# %% [raw]
# ---
# title: Publications
# ---

# %%
import pandas as pd
from utils import get_path

# %%
path_pubs = get_path('INOVA_COVID', 'pubs_469937.csv')
df_pub = pd.read_csv(path_pubs)
df_pub
# Out:
#                                   doi date_inserted  period     type  \
# 0         10.1016/j.tmaid.2019.101549    2020-01-01       1  article
# 1       10.1080/14760584.2020.1711054    2020-01-01       1  article
# 2          10.1007/s00438-019-01638-9    2020-01-03       1  article
# 3              10.1055/s-0039-3401984    2020-01-03       1  article
# 4              10.1126/sciadv.aax5576    2020-01-03       1  article
# ...                               ...           ...     ...      ...
# 469932           10.7759/cureus.20806    2021-12-30       4  article
# 469933           10.7759/cureus.20809    2021-12-30       4  article
# 469934           10.7759/cureus.20810    2021-12-30       4  article
# 469935           10.7759/cureus.20812    2021-12-30       4  article
# 469936           10.7759/cureus.20814    2021-12-30       4  article
#
#         n_authors  n_countries  n_north  n_south first_author_country  \
# 0               2            1      1.0      NaN                   IE
# 1               4            2      2.0      NaN                   DE
# 2               5            1      NaN      1.0                   CN
# 3               4            1      NaN      1.0                   TR
# 4              20            1      NaN      1.0                   CN
# ...           ...          ...      ...      ...                  ...
# 469932          5            1      NaN      1.0                   BR
# 469933          4            1      NaN      1.0                   LB
# 469934          3            1      1.0      NaN                   US
# 469935          5            2      1.0      1.0                   IN
# 469936          5            2      1.0      1.0                   PK
#
#        first_author_income  ... last_author_income distinct_countries  \
# 0                    North  ...              North                 IE
# 1                    North  ...              North             DE; DK
# 2                    South  ...              South                 CN
# 3                    South  ...              South                 TR
# 4                    South  ...              South                 CN
# ...                    ...  ...                ...                ...
# 469932               South  ...              South                 BR
# 469933               South  ...              South                 LB
# 469934               North  ...              North                 US
# 469935               South  ...              North             IN; KW
# 469936               South  ...              North             PK; US
#
#               income category_for_first_level category_for_second_level  \
# 0              North                       11                1103; 1117
# 1       North; North                       11                      1107
# 2              South                       06                0604; 0607
# 3              South                       11                1102; 1103
# 4              South                       11                      1112
# ...              ...                      ...                       ...
# 469932         South                       11                      1103
# 469933         South                       11                      1102
# 469934         North                       11                      1117
# 469935  South; North                       11                      1103
# 469936  South; North                       11                1108; 1117
#
#        category_bra                                           concepts  \
# 0               NaN       travel medicine; medicine research; medicine
# 1            4000.0  adenoviral vaccine vectors; immune response; v...
# 2            4000.0  maize circRNAs; circular RNAs; RNA-seq transcr...
# 3            4001.0  lower respiratory tract infections; respirator...
# 4            4001.0  cetuximab therapy; colorectal cancer; metastat...
# ...             ...                                                ...
# 469932       4001.0  cutaneous manifestations; COVID-19; COVID-19 P...
# 469933       4001.0  infective endocarditis; unusual presentation; ...
# 469934          NaN  ABO blood type; COVID-19 mRNA vaccination; mRN...
# 469935       4001.0  internal carotid artery; right internal caroti...
# 469936       4001.0  positive polymerase chain reaction; primary ca...
#
#                                                      tags adj_list_first  \
# 0                                    North,National,World          IE,IE
# 1                   Norths,Intra_Bloc,International,World       DE,DE,DK
# 2                                    South,National,World          CN,CN
# 3                                    South,National,World          TR,TR
# 4                                    South,National,World          CN,CN
# ...                                                   ...            ...
# 469932                               South,National,World          BR,BR
# 469933                               South,National,World          LB,LB
# 469934                               North,National,World          US,US
# 469935  South_North,Shared_L,Inter_Blocs,International...       IN,IN,KW
# 469936  South_North,Shared_L,Inter_Blocs,International...       PK,PK,US
#
#        adj_list_last
# 0              IE,IE
# 1           DK,DE,DK
# 2              CN,CN
# 3              TR,TR
# 4              CN,CN
# ...              ...
# 469932         BR,BR
# 469933         LB,LB
# 469934         US,US
# 469935      KW,IN,KW
# 469936      US,PK,US
#
# [469937 rows x 21 columns]

# %%
df_pub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469937 entries, 0 to 469936
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   doi                        469937 non-null  object
#  1   date_inserted              469937 non-null  object
#  2   period                     469937 non-null  int64
#  3   type                       469937 non-null  object
#  4   n_authors                  469937 non-null  int64
#  5   n_countries                469937 non-null  int64
#  6   n_north                    334247 non-null  float64
#  7   n_south                    181097 non-null  float64
#  8   first_author_country       469904 non-null  object
#  9   first_author_income        469937 non-null  object
#  10  last_author_country        469904 non-null  object
#  11  last_author_income         469937 non-null  object
#  12  distinct_countries         469915 non-null  object
#  13  income                     469937 non-null  object
#  14  category_for_first_level   431780 non-null  object
#  15  category_for_second_level  406643 non-null  object
#  16  category_bra               172375 non-null  float64
#  17  concepts                   449374 non-null  object
#  18  tags                       469937 non-null  object
#  19  adj_list_first             469937 non-null  object
#  20  adj_list_last              469937 non-null  object
# dtypes: float64(3), int64(3), object(15)
# memory usage: 75.3+ MB

# %%
cols_id = ['doi', 'date_inserted', 'tags']
df_id = df_pub[cols_id]
df_id
# Out:
#                                   doi date_inserted  \
# 0         10.1016/j.tmaid.2019.101549    2020-01-01
# 1       10.1080/14760584.2020.1711054    2020-01-01
# 2          10.1007/s00438-019-01638-9    2020-01-03
# 3              10.1055/s-0039-3401984    2020-01-03
# 4              10.1126/sciadv.aax5576    2020-01-03
# ...                               ...           ...
# 469932           10.7759/cureus.20806    2021-12-30
# 469933           10.7759/cureus.20809    2021-12-30
# 469934           10.7759/cureus.20810    2021-12-30
# 469935           10.7759/cureus.20812    2021-12-30
# 469936           10.7759/cureus.20814    2021-12-30
#
#                                                      tags
# 0                                    North,National,World
# 1                   Norths,Intra_Bloc,International,World
# 2                                    South,National,World
# 3                                    South,National,World
# 4                                    South,National,World
# ...                                                   ...
# 469932                               South,National,World
# 469933                               South,National,World
# 469934                               North,National,World
# 469935  South_North,Shared_L,Inter_Blocs,International...
# 469936  South_North,Shared_L,Inter_Blocs,International...
#
# [469937 rows x 3 columns]

# %%
path_pubs = get_path('INOVA_COVID', 'pubs_doi_date_tag.csv')
df_id.to_csv(path_pubs, index=False)
